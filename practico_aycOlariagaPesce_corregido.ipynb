# %% [markdown]
# # **Análisis y Curación de Datos**
#
# ## **Actividades**
#
# En este práctico partiremos de datos un poco más crudos que los que usamos para el práctico de visualización, e incluiremos algunos más. La idea general es dejar preparado un único dataset que nos permita alimentar futuros modelos de aprendizaje automático.
#
# En primer lugar, partiremos de tres datasets diferentes. Dos de ellos corresponden a información obtenida de la institución médica. Cada uno de ellos consiste en un reporte distinto, que ustedes tendrán que unificar. El tercer dataset contiene información meteorológica, que usaremos en forma complementaria a los datos clínicos. La idea es que una vez que hayan unificado los dos reportes, incluyan la información meteorológica pertinente en el dataset final.
#
# Es importante que cada decisión que tomen sobre los datos quede debidamente documentada.
#
# Se recomienda trabajar empleando algún checklist para asegurarse de cumplir todas las etapas del proceso de curación. Pueden utilizar el checklist que vieron en clase, o algún otro que consideren más apropiado (en las referencias tienen uno a modo de ejemplo).
#
# ### **1. Unificación de los reportes**
#
# La información clínica está dividida en los datasets "turnos_sin_pacientes_2018-2019_despersonalizado.csv" y "turnos_con_pacientes_2018-2019_despersonalizado.csv". Como el nombre lo indica, el primer reporte no contiene información de pacientes, sino sólo información correspondiente a los turnos. El segundo, en cambio, contiene datos de pacientes, pero tiene a su vez menos información sobre los turnos con respecto al primero. Los nombres de los campos en los dos reportes no siempre coinciden. Deberán renombrarlos para que coincidan antes de realizar la unificación. Para unificar los reportes, se recomienda utilizar el método "merge" de pandas.
#
# Nota: En lugar del nombre del paciente, como teníamos en el práctico anterior, ahora contamos con el campo **"HC"** (historia clínica), el cual es un ID único para cada paciente.
#
# #### **Chequeos puntuales por campo**
#
# - Campo **"Estado del Turno"**: Verán que en este campo aparecen categorías que no estaban presentes en el práctico de visualización. Las categorías "Atendidendo", "Asignado" y "Receptado" están asociadas a turnos que estuvieron teniendo lugar en el momento en que se realizó el reporte, o bien, son defectos del sistema. Todas ellas deberán ser recategorizadas como "Atendido". Por otro lado, como nuestro objetivo final es estudiar el ausentismo en pacientes, el cual se define a partir del cociente "Ausentes" / ("Ausentes" + "Atendidos"), sólo nos quedaremos con los turnos que contengan alguna de estas dos categorías.
#
# - Campo **"Edad"**: Este campo puede contiene outliers. Deberán determinarlos y decidir qué hacer con ellos. Por ejemplo, una opción sería descartar los valores que no se encuentren en un determinado rango. Sea cual sea la decisión tomada, es importante que dejen clara cuál es su justificación para tomarla.
#
# - Campo **"Sexo"**: Este campo sólo debería contener las categorías "M" y "F". En caso de que exista otra categoría (por ejemplo, "I"), se la considera un error en la carga de datos, y se le dará el mismo tratamiento que si fuera un valor nulo.
#
# - Campos **"Dirección (localidad y provincia)"**: Van a ver que estos campos son muy sucios (la carga se efectúa manualmente). Acá la recomendación es distinguir sólo si pertenece a la localidad de Córdoba o no, y hacer lo mismo con la provincia de Córdoba.
#
# - Campo **"Nombre del canal"**: Las categorías "Teléfono" y "Call Center" deben ser unificadas, ya que representan lo mismo. La categoría "No definido" debe tratarse de la misma manera que los valores nulos (noten que este campo en particular contiene muchos valores nulos).
#
# - Campo **"Prestador"**: Verificar si hay obras sociales o prepagas que aparezcan con distintos nombres, identificar si hay una categoría que represente a pacientes que no tiene obra social/prepaga, y si hay alguna categoría dudosa.
#
# - Campo **"Fecha"**: Verificar que las fechas pertenecen al rango temporal correspondiente (en este caso, años 2018 y 2019).
#
# - Campo **"Fecha otorgado"**: Esta es la fecha en la que se otorgó el turno. Corroborar que la misma es anterior a la fecha correspondiente al turno.
#
# - Campo **"Prestación Asignada"**: Como vimos en el práctico anterior, este campo tiene categorías con frecuencias muy heterogéneas. La categoría "CONSULTA MEDICA" es por lejos la más frecuente, seguida por "Prestaciones múltiples". Acá deberán evaluar si conviene modificar el campo. Por ejemplo, mantener las categorías más frecuentes y recategorizar las demás como "Otras". En cualquier caso, justifiquen la decisión tomada.
#
# - Campo **"Servicio"**: Identificar los registros correspondientes a consultas de guardia y descartarlos. Explicitar cuál fue el criterio empleado para identificar estos registros.
#
#
# #### **Tests de integridad**
#
# Escriban una función que realice los tests de integridad descriptos anteriormente, y otros que crean correspondientes. La función deberá tomar un dataset, realizar uno por uno los tests, e informar cuáles de ellos fueron exitosos y cuáles no. En el código más adelante hay un template para que les sirva de guía, pero pueden modificarlo a gusto.
#
# #### **Creación de campos nuevos**
#
# Deberán incorporar al dataset al menos un campo nuevo, que crean relevante a la hora de abordar la problemática de la mentoría. Por ejemplo, día de la semana que corresponde al turno, si el paciente es consumidor final o cuenta con obra social/prepaga, etc.
#
# ### **2. Incorporación de información climática**
#
# Los datasets "clima_2018.csv" y "clima_2019.csv" contienen información climática segmentada por día. Esta información es de carácter público y fue obtenida realizando webscrapping del dominio Ogimet (https://www.ogimet.com/gsynres.phtml). Determinen qué información puede ser relevante para la problemática de la mentoría (al menos un campo) e incorporenla al dataset clínico unificado.
#
# ### **3. Opcional**
#
# Los campos **"Recurso"** y **"HC"** en la base de datos original contienen información sensible. En el primer caso, pueden aparecer nombres de personal médico, mientras que el segundo permite identificar unívocamente a los pacientes. En la versión del dataset que tienen ustedes, ambos campos se encuentran codificados. La idea de este opcional es que hagan de cuenta que no están codificados, y que les apliquen algún método de despersonalización. Además de eso, sería bueno que chequeen que no haya otros datos sensibles en otras columnas del dataset.
#
#
# ## Referencias
#
# https://dimewiki.worldbank.org/wiki/Checklist:_Data_Cleaning

# %% [markdown]
# ### Template para tests de integridad

# %%
def test1(df):
    """
    Devuelve 0 si el test es exitoso, y 1 si el test falla
    """
    
    return 1

def test2(df):
    """
    Devuelve 0 si el test es exitoso, y 1 si el test falla
    """
    return 0

def test_integridad(df):
    """
    Ejecuta uno por uno los tests e informa el resultado
    """
        
    print('Test 1: %s' % ('ERROR' if test1(df) else 'EXITOSO'))
    print('Test 2: %s' % ('ERROR' if test2(df) else 'EXITOSO'))
        
    return

test_integridad(1)
# Out:
# Test 1: ERROR
# Test 2: EXITOSO

# %% [markdown]
# #### Importamos paquetes

# %%
import os
import numpy as np
import pandas as pd
import chardet
import string
np.random.seed(0)
import seaborn as sn
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Cargamos los datasets de información climática

# %%
df_clima2018 = pd.read_csv('clima_2018.csv')
df_clima2019 = pd.read_csv('clima_2019.csv')

#df_clima2018 = pd.read_csv(r'E:\anaconda3\envs\mentoria_ausentismo\analisisycuracion\clima_2018.csv')
#df_clima2019 = pd.read_csv(r'E:\anaconda3\envs\mentoria_ausentismo\analisisycuracion\clima_2019.csv')

# %% [markdown]
# #### Concatenamos los dataframes de los años 2018 y 2019

# %%
df_clima = pd.concat([df_clima2018, df_clima2019], ignore_index=True, sort=False)

# %%
df_clima_1 = pd.concat([df_clima2018, df_clima2019], ignore_index=True, sort=False)

# %%
df_clima
# Out:
#           Fecha  Hr.Med(%)  NubTotOct NubbajOct Prec.(mm)  Pres.n. mar(Hp)  \
# 0    01/01/2018       87.6        7.4       5.4      ----           1012.2
# 1    02/01/2018       63.8        3.1       2.3       0.0           1009.1
# 2    03/01/2018       63.7        2.5       1.1       0.0           1008.6
# 3    04/01/2018       43.6        0.6       0.2       0.0           1003.1
# 4    05/01/2018       55.3        2.6       4.8       0.0           1003.6
# ..          ...        ...        ...       ...       ...              ...
# 725  27/12/2019       69.4        5.4       5.4       0.0           1009.7
# 726  28/12/2019       61.3        3.0       2.9       0.0           1006.3
# 727  29/12/2019       87.9        8.0       4.2      10.0           1010.9
# 728  30/12/2019       90.3        7.2       5.6     130.0           1008.3
# 729  31/12/2019       75.5        2.6       1.5       0.0           1009.0
#
#      TdMed(C)  Tmax  Tmed  Tmin Dir.  Rch.  Vel.  VisKm
# 0        16.9  24.2  18.9  16.3   SE  ----   9.3    9.1
# 1        13.3  31.1  22.2  15.6  NNW  ----   7.6   11.4
# 2        15.1  33.0  23.4  15.5  NNE  ----   9.0   14.6
# 3        12.2  35.6  26.9  17.9    N  ----  19.7   12.5
# 4        12.6  37.3  24.3  15.5    S  57.4  22.7   10.5
# ..        ...   ...   ...   ...  ...   ...   ...    ...
# 725      19.1  34.0  25.2  17.0   NE  ----   9.0   10.9
# 726      21.1  36.3  30.0  23.1   NE  ----  15.2   10.9
# 727      21.6  35.1  23.9  20.4    S  ----   8.0    9.6
# 728      21.5  29.6  23.5  20.8  SSW  51.9   9.3    8.2
# 729      20.6  32.3  25.8  19.7  SSE  ----  11.2   12.8
#
# [730 rows x 14 columns]

# %% [markdown]
# #### Renombramos las columnas ya que presentan caracteres especiales en los nombres

# %%
to_rename = {
    'Fecha' : 'FechaDiaDelTurno' ,
    'Hr.Med(%)': 'HrMedPorcentaje',
    'Prec.(mm)': 'PrecipMM',
    'Pres.n. mar(Hp)': 'PresionHp',
    'TdMed(C)': 'TempMedCentigrados',
    'Dir.': 'Direccion',
    'Rch.': 'Rch',
    'Vel.': 'Vel',
            }
df_clima_r = df_clima.rename(columns=to_rename)

# %%
df_clima_r.PrecipMM.unique()
# Out:
# array(['----', '0.0', 'Ip', '8.3', '12.0', '4.3', '19.0', '8.9', '1.0',
#        '4.0', '15.0', '33.5', '14.0', '3.0', '0.8', '0.7', '11.0', '3.8',
#        '3.7', '1.1', '2.0', '10.7', '4.9', '50.0', '26.7', '23.0', '10.0',
#        '0.2', '1.6', '8.0', '6.3', '0.9', '0.5', '6.0', '1.3', '0.6',
#        '7.0', '24.0', '5.0', '18.0', '20.0', '7.1', '15.4', '9.0', '5.5',
#        '11.6', '57.0', '13.0', '20.3', '31.0', '29.0', '32.0', '96.0',
#        '16.7', '0.4', '16.0', '33.0', '6.2', '0.3', '0.1', '13.3', '17.0',
#        '13.7', '15.9', '2.2', '25.0', '9.8', '3.1', '1.7', '5.3', '2.6',
#        '39.0', '1.5', '1.2', '12.7', '62.0', '16.2', '28.0', '130.0'],
#       dtype=object)

# %%
df_clima_r.dtypes
# Out:
# FechaDiaDelTurno       object
# HrMedPorcentaje       float64
# NubTotOct             float64
# NubbajOct              object
# PrecipMM               object
# PresionHp             float64
# TempMedCentigrados    float64
# Tmax                  float64
# Tmed                  float64
# Tmin                  float64
# Direccion              object
# Rch                    object
# Vel                   float64
# VisKm                 float64
# dtype: object

# %% [markdown]
# #### Nos quedamos solamente con la columna de precipitaciones para incluirla en el data frame final

# %%
df_clima_r = df_clima_r.drop(['HrMedPorcentaje', 'NubTotOct', 'NubbajOct', 'PresionHp', 
             'TempMedCentigrados', 'Tmax', 'Tmed', 'Tmin', 'Direccion', 
             'Rch', 'Vel', 'VisKm'], axis=1)

# %%
df_clima_r
# Out:
#     FechaDiaDelTurno PrecipMM
# 0         01/01/2018     ----
# 1         02/01/2018      0.0
# 2         03/01/2018      0.0
# 3         04/01/2018      0.0
# 4         05/01/2018      0.0
# ..               ...      ...
# 725       27/12/2019      0.0
# 726       28/12/2019      0.0
# 727       29/12/2019     10.0
# 728       30/12/2019    130.0
# 729       31/12/2019      0.0
#
# [730 rows x 2 columns]

# %% [markdown]
# #### Cargamos los datasets clínicos

# %%
dfp = pd.read_csv('turnos_con_paciente_2018-2019_despersonalizado.csv', sep=';')
dfsp = pd.read_csv('turnos_sin_paciente_2018-2019_despersonalizado.csv', sep=';')

#dfp = pd.read_csv(r'E:\anaconda3\envs\mentoria_ausentismo\analisisycuracion\turnos_con_paciente_2018-2019_despersonalizado.csv', sep=';')
#dfsp = pd.read_csv(r'E:\anaconda3\envs\mentoria_ausentismo\analisisycuracion\turnos_sin_paciente_2018-2019_despersonalizado.csv', sep=';')

# %% [markdown]
# #### Renombramos columnas dfsp

# %%
## Renombramos columnas
to_rename = {
    'Centro de atención': 'CentroDeAtencion',
    'Prestación asignada': 'Prestacion',
    'Estado del turno': 'EstadoDelTurno',
    'Nombre del canal': 'Canal',
    'Fecha del turno': 'FechaDelTurno',
    'Hora del turno': 'HoraDelTurno',
    'Es sobre turno': 'EsSobreTurno',
    'Tipo de turno asignado': 'TipoDeTurno'
        }
dfsp_r = dfsp.rename(columns=to_rename)

# %%
## Parseamos fechas
dfsp_r.FechaDelTurno = dfsp_r.FechaDelTurno + ' ' + dfsp_r.HoraDelTurno
dfsp_r.FechaDelTurno = pd.to_datetime(dfsp_r.FechaDelTurno)
dfsp_r = dfsp_r.drop(columns=['HoraDelTurno'])

# %%
dfsp_r.dtypes
# Out:
# CentroDeAtencion             int64
# Servicio                    object
# Recurso                      int64
# Prestacion                  object
# EstadoDelTurno              object
# Canal                       object
# FechaDelTurno       datetime64[ns]
# EsSobreTurno                object
# TipoDeTurno                 object
# dtype: object

# %% [markdown]
# #### Renombramos columnas dfp

# %%
## Renombramos columnas
to_rename = {
    'CentroAtencion_Nombre': 'CentroDeAtencion',
    'Servicio_Nombre': 'Servicio',
    'TurnoEstado_Nombre': 'EstadoDelTurno',
    'FechaTurno': 'FechaDelTurno',
    'TipoTurno': 'TipoDeTurno',
    'Dirección (localidad)' : 'Localidad',
    'Dirección (provincia)' : 'Provincia',
    'FechaOtrogado' : 'FechaOtorgado'
    }
dfp_r = dfp.rename(columns=to_rename)

# %%
## Parseamos fechas
dfp_r.FechaDelTurno = pd.to_datetime(dfp_r.FechaDelTurno)

# %%
dfp_r.dtypes
# Out:
# CentroDeAtencion             int64
# Prestador                   object
# Recurso                      int64
# Servicio                    object
# FechaDelTurno       datetime64[ns]
# EstadoDelTurno              object
# Sexo                        object
# Edad                         int64
# HC                         float64
# TipoDeTurno                 object
# Prestacion                  object
# FechaOtorgado               object
# Localidad                   object
# Provincia                   object
# dtype: object

# %% [markdown]
# ### Chequeo puntual de localidad y provincia

# %% [markdown]
# #### Mostramos los valores posibles de localidad

# %%
dfp_r['Localidad'].value_counts()
# Out:
# -                              1001679
# CORDOBA                         447738
# CORDOBA CAPITAL                  25844
# MONTE CRISTO                      5989
# RIO CEBALLOS                      5793
#                                 ...
# AHIMOGASTA                           1
# MARHUL                               1
# MORON                                1
# DALMACIO VELEZ SARSFIELD             1
# PRESIDENTE ROQUE SAENZ PEÑA          1
# Name: Localidad, Length: 849, dtype: int64

# %% [markdown]
# #### Mostramos los valores posibles de provincia

# %%
dfp_r['Provincia'].unique()
# Out:
# array(['-', nan, 'CORDOBA', 'CÓRDOBA', 'RIO NEGRO', 'LA RIOJA',
#        'SANTA FE', 'MENDOZA', 'SANTIAGO DEL ESTERO', 'TIERRA DEL FUEGO',
#        'SANTA CRUZ', 'TIRRA DEL FUEGO', 'JUJUY', 'SALTA', 'BAHIA BLANCA',
#        'SAN JUAN', 'SAN LUIS', 'TUCUMAN', 'BUENOS AIRES', 'ENTRE RIOS',
#        'LA PAMPA', 'MISIONES', 'GOLF (ALTA GRACIA)', 'CORRIENTES',
#        'CATAMARCA', 'Córdoba', 'NEUQUEN', 'CORODBA', 'FORMOSA',
#        'SAN FRANCISCO', 'CORDOBA CAPITAL', 'RIO GALLEGOS',
#        'SANTIAGO  DEL ESTERO', 'STA CRUZ', 'CHILECITO LA RIOJA', 'CHUBUT',
#        'VALLE CERCANOAÇ', 'BS.AS', 'CORDO', 'SANTIGO DEL ESTERO',
#        'LABOULAYE', 'BOLIVIA', 'STA FE', 'ADELIA MARIA',
#        'SAN SALVADOR DE JUJUY', 'LARIOJA', 'VILLA ALLENDE', 'CHACO',
#        'CRUZ DEL EJE', 'RIO TERCERO', 'RIO CUARTO', 'FRONTERA-SANTA FE',
#        'SAN  LUIS', 'SUNCHALES', 'SANB LUIS', 'BS AS', 'CORDOBA.',
#        'CAPITAL FEDERAL', 'FREYRE', 'STO DEL ESTERO'], dtype=object)

# %% [markdown]
# #### Convertimos las diferentes formas de escribir Cordoba por cordoba

# %%
import re
import unidecode
##Hacemos minúscula todo
dfp_r.Localidad = dfp_r.Localidad.str.lower()
dfp_r.Provincia = dfp_r.Provincia.str.lower()

# %%
dfp_r.Localidad.replace(['-', ' '], 'No definido', inplace=True)
dfp_r.loc[dfp_r.Localidad.isnull(), 'Localidad'] = 'No definido'
dfp_r.Provincia.replace(['-', ' '], 'No definido', inplace=True)
dfp_r.loc[dfp_r.Provincia.isnull(), 'Provincia'] = 'No definido'

# %%
##Reemplazamos todos los _Córdoba_ mal escritos (ya revisados) por "cordoba"
Mal_Escrito = ['cba', 'cordiba', 'cordo', 'cordobacapital', 'cordobacapitral', 'cordonba', 'corodba', 'crdoba', 'ordoba']
dfp_r.Localidad.replace(Mal_Escrito,'cordoba', inplace=True)
dfp_r.Provincia.replace(Mal_Escrito,'cordoba', inplace=True)

# %%
#Localidad
##Evaluamos y reemplazamos los que tenemos dudas (ya revisados), por "cordoba" 
Duda = ['capital', 'centro']
dfp_r.loc[(dfp_r.Provincia == 'cordoba') & (dfp_r.Localidad.isin(Duda)), 'Localidad'] = 'cordoba'

# %%
#Provincia
##Reemplazamos los posibles "nodefinido" por "cordoba" en Provincia, cuando Localidad='cordoba'
dfp_r.loc[dfp_r.Localidad == 'cordoba', 'Provincia'] = 'cordoba'

# %%
##Reemplazamos todo lo que no es "cordoba" por "otro"
dfp_r.loc[(dfp_r.Provincia != 'cordoba') , 'Provincia'] = 'otro'
dfp_r.loc[(dfp_r.Provincia == 'nodefinido'), 'Provincia'] = 'otro'
dfp_r.loc[(dfp_r.Localidad != 'cordoba') , 'Localidad'] = 'otro'
dfp_r.loc[(dfp_r.Localidad == 'nodefinido'), 'Localidad'] = 'otro'

# %%
dfp_r['Localidad'].value_counts()
# Out:
# otro       2313324
# cordoba     449266
# Name: Localidad, dtype: int64

# %%
dfp_r['Provincia'].value_counts()
# Out:
# otro       2076294
# cordoba     686296
# Name: Provincia, dtype: int64

# %% [markdown]
# ### Chequeo puntual de Estado del Turno

# %% [markdown]
# #### dfp_r: cambiamos el contenido de EstadoDelTurno para que "Asignado", "Receptado" y "Atendiendo" tengan el valor Atendido

# %%
dfp_r.EstadoDelTurno= dfp_r.EstadoDelTurno.replace ({'Atendiendo' :'Atendido','Asignado':'Atendido','Receptado':'Atendido'})

# %%
dfp_r.sample(10)
# Out:
#          CentroDeAtencion                    Prestador  Recurso  \
# 2516415                 2     OMINT S. A. DE SERVICIOS       48
# 1880274                 2             CONSUMIDOR FINAL      171
# 905507                  1                            -      517
# 899189                  1                            -      119
# 2755412                 2                        OSDE       173
# 462562                  1               FEDERADA SALUD       98
# 395052                  4  NOBIS S.A. MEDICINA PRIVADA      506
# 796923                  3                        IOSFA      134
# 2056773                 1                      SANCOR       271
# 22285                   1     OMINT S. A. DE SERVICIOS      124
#
#                          Servicio       FechaDelTurno EstadoDelTurno Sexo  \
# 2516415              REUMATOLOGÍA 2019-11-06 18:00:00        Ausente    F
# 1880274                 ECOGRAFIA 2019-06-19 15:45:00        Anulado    F
# 905507                GINECOLOGÍA 2018-09-25 15:45:00       Inactivo
# 899189       DEMANDA DE PEDIATRÍA 2018-09-24 13:45:00          Libre
# 2755412                 ECOGRAFIA 2019-12-30 08:00:00       Atendido    M
# 462562   GINECOLOGIA PRACTICAS CP 2018-05-18 18:00:00        Anulado    F
# 395052    KINESIOL Y FISIOTERAPIA 2018-04-25 15:50:00        Anulado    M
# 796923                  PEDIATRÍA 2018-08-27 15:20:00        Anulado    F
# 2056773           HOSPITAL DE DÍA 2019-07-26 17:15:00       Atendido    F
# 22285         CIRUGÍA GENERAL INF 2018-01-08 21:41:00       Atendido    M
#
#          Edad        HC         TipoDeTurno                   Prestacion  \
# 2516415    49   20195.0  Ulterior / Control              CONSULTA MEDICA
# 1880274    38  104881.0            Práctica  ECOGRAFIA TOCOGINECOLÓGICA
# 905507      0       NaN                 NaN                          NaN
# 899189      0       NaN                 NaN                          NaN
# 2755412    43   13584.0            Práctica             ECO DOPPLER MMII
# 462562     40    7142.0            Práctica  COLPOSCOPIA -TRAQUELOSCOPIA
# 395052     33   13928.0            Práctica    REHABILITACION DE RODILLA
# 796923      1   80661.0         Primera Vez              CONSULTA MEDICA
# 2056773    36     545.0            Práctica    QUIMIOTERAPIA AMBULATORIA
# 22285      17    6455.0         Primera Vez       Prestaciones multiples
#
#                       FechaOtorgado Localidad Provincia
# 2516415  2019-10-23 18:43:28.723000   cordoba   cordoba
# 1880274  2019-06-13 11:09:50.080000      otro      otro
# 905507                          NaN      otro      otro
# 899189                          NaN      otro      otro
# 2755412  2019-12-27 13:48:06.003000      otro   cordoba
# 462562   2018-05-09 13:46:57.913000      otro      otro
# 395052   2018-04-10 16:20:36.957000   cordoba   cordoba
# 796923   2018-08-22 13:57:17.373000      otro      otro
# 2056773  2019-07-24 14:44:10.493000      otro      otro
# 22285    2018-01-08 21:41:43.337000      otro   cordoba

# %% [markdown]
# #### Nos quedamos solo con Estados del Turno Atendido y Ausente

# %%
dfsp_r_t= dfsp_r[dfsp_r.EstadoDelTurno.isin (['Atendido','Ausente'])]

# %%
dfsp_r_t
# Out:
#          CentroDeAtencion              Servicio  Recurso  \
# 0                       1  GUARDIA DE PEDIATRIA      253
# 1                       1  GUARDIA DE PEDIATRIA      253
# 2                       1  GUARDIA DE PEDIATRIA      253
# 3                       1  GUARDIA DE PEDIATRIA      253
# 4                       1  GUARDIA DE PEDIATRIA      253
# ...                   ...                   ...      ...
# 2196194                 1           RADIOGRAFIA      454
# 2196269                 1             ECOGRAFIA      174
# 2196272                 1             ECOGRAFIA      174
# 2196401                 1             ECOGRAFIA      174
# 2196512                 1           RADIOGRAFIA      454
#
#                             Prestacion EstadoDelTurno Canal  \
# 0                      CONSULTA MEDICA       Atendido   NaN
# 1                      CONSULTA MEDICA       Atendido   NaN
# 2                      CONSULTA MEDICA       Atendido   NaN
# 3            COLOCACION DE INYECTABLES       Atendido   NaN
# 4                      CONSULTA MEDICA       Atendido   NaN
# ...                                ...            ...   ...
# 2196194         Prestaciones multiples       Atendido   NaN
# 2196269  ECOGRAFIA COMPLETA DE ABDOMEN       Atendido   NaN
# 2196272    ECOGRAFIA DE PARTES BLANDAS       Atendido   NaN
# 2196401         ECOGRAFIA TRANSVAGINAL       Atendido   NaN
# 2196512         Prestaciones multiples       Atendido   NaN
#
#               FechaDelTurno EsSobreTurno         TipoDeTurno
# 0       2018-01-01 02:31:00           SI  Ulterior / Control
# 1       2018-01-01 03:09:00           SI  Ulterior / Control
# 2       2018-01-01 03:23:00           SI  Ulterior / Control
# 3       2018-01-01 03:47:00           SI  Ulterior / Control
# 4       2018-01-01 03:51:00           SI  Ulterior / Control
# ...                     ...          ...                 ...
# 2196194 2019-12-30 23:30:00           SI            Práctica
# 2196269 2019-12-31 09:24:00           SI            Práctica
# 2196272 2019-12-31 09:27:00           SI            Práctica
# 2196401 2019-12-31 11:29:00           SI            Práctica
# 2196512 2019-12-31 14:23:00           SI            Práctica
#
# [1224004 rows x 9 columns]

# %% [markdown]
# ### Hacemos el merge de los dos dataframes

# %%
dfp_r.dtypes
# Out:
# CentroDeAtencion             int64
# Prestador                   object
# Recurso                      int64
# Servicio                    object
# FechaDelTurno       datetime64[ns]
# EstadoDelTurno              object
# Sexo                        object
# Edad                         int64
# HC                         float64
# TipoDeTurno                 object
# Prestacion                  object
# FechaOtorgado               object
# Localidad                   object
# Provincia                   object
# dtype: object

# %%
dfsp_r_t.dtypes
# Out:
# CentroDeAtencion             int64
# Servicio                    object
# Recurso                      int64
# Prestacion                  object
# EstadoDelTurno              object
# Canal                       object
# FechaDelTurno       datetime64[ns]
# EsSobreTurno                object
# TipoDeTurno                 object
# dtype: object

# %%
cols = [
    'CentroDeAtencion', 'Servicio', 'Recurso', 'FechaDelTurno', 
    'EstadoDelTurno', 'Prestacion', 'TipoDeTurno'
]
df = dfp_r.merge(dfsp_r_t, on=cols)
df.head()
# Out:
#    CentroDeAtencion                Prestador  Recurso              Servicio  \
# 0                 1  MEDIFE ASOCIACIÓN CIVIL      253  GUARDIA DE PEDIATRIA
# 1                 1  MEDIFE ASOCIACIÓN CIVIL      253  GUARDIA DE PEDIATRIA
# 2                 1                    DASPU      253  GUARDIA DE PEDIATRIA
# 3                 1       SWISS MEDICAL S.A.      253  GUARDIA DE PEDIATRIA
# 4                 1        PARQUE SALUD S.A.      253  GUARDIA DE PEDIATRIA
#
#         FechaDelTurno EstadoDelTurno Sexo  Edad   HC         TipoDeTurno  \
# 0 2018-01-01 11:57:00       Atendido    F     4  0.0  Ulterior / Control
# 1 2018-01-01 12:20:00       Atendido    M     3  1.0  Ulterior / Control
# 2 2018-01-01 12:23:00       Atendido    M     3  2.0  Ulterior / Control
# 3 2018-01-01 12:27:00       Atendido    M     3  3.0  Ulterior / Control
# 4 2018-01-01 12:38:00       Atendido    F     3  4.0  Ulterior / Control
#
#         Prestacion               FechaOtorgado Localidad Provincia Canal  \
# 0  CONSULTA MEDICA  2018-01-01 11:58:10.047000      otro      otro   NaN
# 1  CONSULTA MEDICA  2018-01-01 12:20:46.097000      otro      otro   NaN
# 2  CONSULTA MEDICA  2018-01-01 12:25:39.333000      otro      otro   NaN
# 3  CONSULTA MEDICA  2018-01-01 12:27:55.193000      otro      otro   NaN
# 4  CONSULTA MEDICA  2018-01-01 12:39:04.563000      otro      otro   NaN
#
#   EsSobreTurno
# 0           SI
# 1           SI
# 2           SI
# 3           SI
# 4           SI

# %%
df.dtypes
# Out:
# CentroDeAtencion             int64
# Prestador                   object
# Recurso                      int64
# Servicio                    object
# FechaDelTurno       datetime64[ns]
# EstadoDelTurno              object
# Sexo                        object
# Edad                         int64
# HC                         float64
# TipoDeTurno                 object
# Prestacion                  object
# FechaOtorgado               object
# Localidad                   object
# Provincia                   object
# Canal                       object
# EsSobreTurno                object
# dtype: object

# %% [markdown]
# ### Chequeo puntual del Canal

# %% [markdown]
# #### Unificamos en canal teléfono y call center como teléfono

# %%
df.loc[(df.Canal == 'Teléfono'), 'Canal'] = 'Telefono'

# %%
df.loc[(df.Canal == 'Call Center'), 'Canal'] = 'Telefono'

# %%
df.Canal.unique()
# Out:
# array([nan, 'Recepción', 'Telefono', 'Turnos Online', 'No Definido',
#        'Chat/Redes Sociales'], dtype=object)

# %% [markdown]
# ### Chequeo puntual de los valores de la variable Sexo

# %% [markdown]
# #### Dejamos solo F y M como valores posibles de sexo

# %%
df_1= df[df.Sexo.isin (['F','M'])]

# %%
df_1['Sexo'].value_counts()
# Out:
# F    781969
# M    528531
# Name: Sexo, dtype: int64

# %% [markdown]
# #### Convertimos HC de float a integer

# %%
df_1.HC = df_1.HC.astype(int)

# %%
df_1.HC.unique()
# Out:
# array([     0,      1,      2, ..., 169378, 169487, 169488])

# %% [markdown]
# ### Chequeo puntual de la variable Edad

# %% [markdown]
# #### Edad

# %%
print (df_1.Edad.min())
print (df_1.Edad.max())
# Out:
# 0
# 120

# %% [markdown]
# #### Sacamos outliers el caso de edad = 120

# %%
df_1.loc[(df_1.Edad == 120)]
# Out:
#          CentroDeAtencion                      Prestador  Recurso  \
# 7050                    1               CONSUMIDOR FINAL      497
# 11329                   1                          DASPU      511
# 11987                   1               CONSUMIDOR FINAL      497
# 14753                   1               CONSUMIDOR FINAL      315
# 15755                   1               CONSUMIDOR FINAL      505
# ...                   ...                            ...      ...
# 1294233                 1               CONSUMIDOR FINAL      243
# 1298139                 3  CONSEJO  PROF. CS. ECONOMICAS      423
# 1298851                 1       OMINT S. A. DE SERVICIOS      341
# 1301914                 3        MEDIFE ASOCIACIÓN CIVIL      511
# 1304997                 2               CONSUMIDOR FINAL       54
#
#                       Servicio       FechaDelTurno EstadoDelTurno Sexo  Edad  \
# 7050     ANATOMÍA PATOLÓGICA B 2018-01-08 08:32:00       Atendido    M   120
# 11329                NUTRICIÓN 2018-01-10 15:00:00        Ausente    M   120
# 11987    ANATOMÍA PATOLÓGICA B 2018-01-10 10:48:00       Atendido    M   120
# 14753    DIABETOLOGIA Y NUTRIC 2018-01-11 17:00:00        Ausente    M   120
# 15755        GASTROENTEROLOGÍA 2018-01-12 12:00:00        Ausente    M   120
# ...                        ...                 ...            ...  ...   ...
# 1294233   OTORRINOLARINGOLOGÍA 2019-12-19 18:00:00       Atendido    M   120
# 1298139           DERMATOLOGÍA 2019-12-20 09:00:00       Atendido    M   120
# 1298851              MICOLOGIA 2019-12-21 10:17:00       Atendido    F   120
# 1301914              NUTRICIÓN 2019-12-23 14:45:00       Atendido    M   120
# 1304997   ORTOPEDIA Y TRAUMATO 2019-12-26 17:05:00       Atendido    F   120
#
#              HC         TipoDeTurno  \
# 7050       6076            Práctica
# 11329      8964            Práctica
# 11987      9390            Práctica
# 14753     10942         Primera Vez
# 15755     11501         Primera Vez
# ...         ...                 ...
# 1294233  168511         Primera Vez
# 1298139  168699         Primera Vez
# 1298851  168734         Primera Vez
# 1301914  159048            Práctica
# 1304997  166968  Ulterior / Control
#
#                                               Prestacion  \
# 7050     ESTUDIO HISTOPATOLOGICO DE PIEZA OPERATORIA SNC
# 11329                 CONTROL DIETA DIABETES GESTACIONAL
# 11987                          ESTUDIO CITOLOGICO DE LCR
# 14753                                    CONSULTA MEDICA
# 15755                                    CONSULTA MEDICA
# ...                                                  ...
# 1294233                                  CONSULTA MEDICA
# 1298139                                  CONSULTA MEDICA
# 1298851                                  CONSULTA MEDICA
# 1301914                                 PLAN NUTRICIONAL
# 1304997                                  CONSULTA MEDICA
#
#                       FechaOtorgado Localidad Provincia      Canal  \
# 7050     2018-01-08 08:34:58.490000      otro      otro        NaN
# 11329    2017-12-26 15:19:43.773000   cordoba   cordoba  Recepción
# 11987    2018-01-10 10:50:40.477000      otro      otro        NaN
# 14753    2017-12-15 08:44:17.427000      otro      otro  Recepción
# 15755    2018-01-12 11:28:48.173000      otro      otro  Recepción
# ...                             ...       ...       ...        ...
# 1294233  2019-12-12 18:26:38.430000   cordoba   cordoba   Telefono
# 1298139  2019-11-29 11:48:09.193000   cordoba   cordoba  Recepción
# 1298851  2019-12-20 17:17:37.237000   cordoba   cordoba        NaN
# 1301914  2019-12-13 11:14:45.160000      otro      otro  Recepción
# 1304997  2019-12-18 10:40:32.537000      otro   cordoba        NaN
#
#         EsSobreTurno
# 7050              SI
# 11329             NO
# 11987             SI
# 14753             NO
# 15755             NO
# ...              ...
# 1294233           NO
# 1298139           NO
# 1298851           SI
# 1301914           NO
# 1304997           SI
#
# [488 rows x 16 columns]

# %%
df_1 = df_1.drop(df_1[df_1['Edad'] == 120].index)

# %%
print (df_1.Edad.min())
print (df_1.Edad.max())
# Out:
# 0
# 102

# %%
df_1.loc[(df_1.Edad == 102)]
# Out:
#          CentroDeAtencion         Prestador  Recurso        Servicio  \
# 48279                   1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
# 70459                   1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
# 109856                  1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
# 124043                  1  CONSUMIDOR FINAL      347     HEMATOLOGÍA
# 176898                  1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
# 276974                  1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
# 419448                  1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
# 452464                  1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
# 740396                  1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
# 742473                  1  CONSUMIDOR FINAL      490      NEUROLOGÍA
# 1070129                 2  CONSUMIDOR FINAL       62     HEMATOLOGÍA
# 1262142                 2  CONSUMIDOR FINAL       62     HEMATOLOGÍA
# 1283580                 1  CONSUMIDOR FINAL      256  CLÍNICA MÉDICA
#
#               FechaDelTurno EstadoDelTurno Sexo  Edad     HC  \
# 48279   2018-02-06 15:45:00       Atendido    F   102  25522
# 70459   2018-02-22 14:10:00       Atendido    F   102  25522
# 109856  2018-03-19 16:10:00       Atendido    F   102  25522
# 124043  2018-03-27 14:40:00       Atendido    F   102  25522
# 176898  2018-05-04 13:30:00       Atendido    F   102  25522
# 276974  2018-07-10 17:00:00       Atendido    F   102  25522
# 419448  2018-10-01 15:55:00       Atendido    F   102  25522
# 452464  2018-10-19 15:39:00       Atendido    F   102  25522
# 740396  2019-04-05 16:20:00       Atendido    F   102  25522
# 742473  2019-04-05 11:45:00       Atendido    F   102  25522
# 1070129 2019-09-12 18:00:00       Atendido    F   102  25522
# 1262142 2019-12-05 18:30:00       Atendido    F   102  25522
# 1283580 2019-12-16 18:00:00       Atendido    F   102  25522
#
#                 TipoDeTurno                     Prestacion  \
# 48279    Ulterior / Control                CONSULTA MEDICA
# 70459    Ulterior / Control                CONSULTA MEDICA
# 109856   Ulterior / Control                CONSULTA MEDICA
# 124043   Ulterior / Control                CONSULTA MEDICA
# 176898   Ulterior / Control                CONSULTA MEDICA
# 276974   Ulterior / Control                CONSULTA MEDICA
# 419448          Primera Vez                CONSULTA MEDICA
# 452464   Ulterior / Control                CONSULTA MEDICA
# 740396   Ulterior / Control                CONSULTA MEDICA
# 742473          Primera Vez                CONSULTA MEDICA
# 1070129            Práctica  CONSULTA DIFERENCIADA MAT-INF
# 1262142  Ulterior / Control       CONSULTA MEDICA MAT- INF
# 1283580  Ulterior / Control                CONSULTA MEDICA
#
#                       FechaOtorgado Localidad Provincia     Canal EsSobreTurno
# 48279    2018-02-06 15:39:01.840000      otro      otro       NaN           SI
# 70459    2018-02-20 15:03:00.660000      otro      otro       NaN           SI
# 109856   2018-03-12 14:26:00.730000      otro      otro       NaN           SI
# 124043   2018-03-19 17:00:24.720000      otro      otro       NaN           SI
# 176898   2018-05-04 13:32:26.623000      otro      otro       NaN           SI
# 276974   2018-06-27 19:12:47.060000      otro      otro  Telefono           NO
# 419448   2018-10-01 15:36:08.403000      otro      otro       NaN           SI
# 452464   2018-10-19 15:40:03.713000      otro      otro       NaN           SI
# 740396   2019-03-13 11:36:02.110000      otro      otro  Telefono           NO
# 742473   2019-03-28 19:29:30.157000      otro      otro  Telefono           NO
# 1070129  2019-09-06 16:18:31.540000      otro      otro       NaN           SI
# 1262142  2019-11-28 18:32:11.437000      otro      otro       NaN           SI
# 1283580  2019-12-02 10:40:50.990000      otro      otro       NaN           NO

# %% [markdown]
# ### Chequeo puntual Prestador

# %% [markdown]
# #### En Prestador solo dejamos los valores Consumidor Final y Otro

# %%
df_1.Prestador.value_counts()
# Out:
# OSDE                           173696
# SWISS MEDICAL S.A.             138362
# OMINT S. A. DE SERVICIOS       135427
# MEDIFE ASOCIACIÓN CIVIL        108408
# SANCOR                         104293
#                                 ...
# PREMED                            104
# HOSPITAL ALEMÁN ASOC.CIVIL         98
# ECCO S.A.                          29
# HOPE                                3
# MINISTERIO DE SALUD DE CBA.         3
# Name: Prestador, Length: 74, dtype: int64

# %%
##Reemplazamos todo lo que no es "consumidor final" por "otro"
df_1.loc[(df_1.Prestador != 'CONSUMIDOR FINAL') , 'Prestador'] = 'OTRO'

# %%
df_1.Prestador.value_counts()
# Out:
# OTRO                1206247
# CONSUMIDOR FINAL     103765
# Name: Prestador, dtype: int64

# %% [markdown]
# ### Chequeo puntual de la fecha del turno

# %% [markdown]
# #### Controlamos que la fecha del turno este entre 2018 y 2019

# %%
df_1.FechaDelTurno.min()
# Out:
# Timestamp('2018-01-01 02:31:00')

# %%
df_1.FechaDelTurno.max()
# Out:
# Timestamp('2019-12-31 14:23:00')

# %%
df_1.FechaDelTurno.value_counts()
# Out:
# 2018-09-25 15:30:00    135
# 2019-12-04 14:30:00    123
# 2019-10-30 10:00:00    121
# 2019-10-31 16:30:00    120
# 2018-10-09 15:30:00    119
#                       ...
# 2019-10-24 08:57:00      1
# 2018-10-10 10:48:00      1
# 2018-10-08 19:44:00      1
# 2019-11-11 11:58:00      1
# 2018-10-24 09:57:00      1
# Name: FechaDelTurno, Length: 167577, dtype: int64

# %% [markdown]
# ####  Controlamos que la fecha otorgado del turno sea menor que la fecha del turno

# %%
df_1['FechaOtorgado'] = pd.to_datetime(df.FechaOtorgado)

# %%
df_1['FechaOtorgado'].min()
# Out:
# Timestamp('2017-11-29 14:36:56.490000')

# %%
df_1['FechaOtorgado'].max()
# Out:
# Timestamp('2019-12-31 14:23:49.333000')

# %%
df_1['FechaDiaDelTurno'] = [d.date() for d in df_1['FechaDelTurno']]
df_1['HoraTurno'] = [d.time() for d in df_1['FechaDelTurno']]

# %%
df_1['FechaDiaOtorgado'] = [d.date() for d in df_1['FechaOtorgado']]
df_1['HoraOtorgado'] = [d.time() for d in df_1['FechaOtorgado']]

# %%
df_1['DifDias'] = df_1.FechaDiaDelTurno - df_1.FechaDiaOtorgado

# %%
x=pd.Timedelta(0,'d')

# %%
df_1.loc[(df_1.DifDias < x)]
# Out:
#          CentroDeAtencion         Prestador  Recurso     Servicio  \
# 871009                  1              OTRO      174    ECOGRAFIA
# 969969                  1  CONSUMIDOR FINAL      456  RADIOGRAFIA
# 973213                  1  CONSUMIDOR FINAL      456  RADIOGRAFIA
# 974086                  1  CONSUMIDOR FINAL      499   TOMOGRAFIA
# 1011569                 1              OTRO      499   TOMOGRAFIA
# 1124223                 2              OTRO      172    ECOGRAFIA
# 1199440                 1              OTRO      499   TOMOGRAFIA
# 1223458                 2              OTRO      173    ECOGRAFIA
#
#               FechaDelTurno EstadoDelTurno Sexo  Edad      HC TipoDeTurno  \
# 871009  2019-06-11 13:05:00       Atendido    M    14  139195    Práctica
# 969969  2019-07-31 15:00:00       Atendido    M     3  123800    Práctica
# 973213  2019-08-02 11:42:00       Atendido    F    79   22860    Práctica
# 974086  2019-08-01 18:40:00       Atendido    F    79   22860    Práctica
# 1011569 2019-08-19 12:52:00       Atendido    M    67   44687    Práctica
# 1124223 2019-10-07 11:16:00       Atendido    M    76   37665    Práctica
# 1199440 2019-11-10 10:00:00       Atendido    M    63  162700    Práctica
# 1223458 2019-11-19 16:01:00       Atendido    M    63  162484    Práctica
#
#          ...           FechaOtorgado Localidad Provincia Canal EsSobreTurno  \
# 871009   ... 2019-06-12 13:06:29.367      otro      otro   NaN           SI
# 969969   ... 2019-08-07 10:46:01.643      otro      otro   NaN           SI
# 973213   ... 2019-08-05 11:43:20.167   cordoba   cordoba   NaN           SI
# 974086   ... 2019-08-02 18:41:01.573   cordoba   cordoba   NaN           SI
# 1011569  ... 2019-08-20 12:53:10.350      otro   cordoba   NaN           SI
# 1124223  ... 2019-10-08 08:16:50.597   cordoba   cordoba   NaN           SI
# 1199440  ... 2019-11-20 10:54:27.297      otro      otro   NaN           SI
# 1223458  ... 2019-11-21 13:37:06.597      otro      otro   NaN           SI
#
#         FechaDiaDelTurno HoraTurno FechaDiaOtorgado     HoraOtorgado  DifDias
# 871009        2019-06-11  13:05:00       2019-06-12  13:06:29.367000  -1 days
# 969969        2019-07-31  15:00:00       2019-08-07  10:46:01.643000  -7 days
# 973213        2019-08-02  11:42:00       2019-08-05  11:43:20.167000  -3 days
# 974086        2019-08-01  18:40:00       2019-08-02  18:41:01.573000  -1 days
# 1011569       2019-08-19  12:52:00       2019-08-20  12:53:10.350000  -1 days
# 1124223       2019-10-07  11:16:00       2019-10-08  08:16:50.597000  -1 days
# 1199440       2019-11-10  10:00:00       2019-11-20  10:54:27.297000 -10 days
# 1223458       2019-11-19  16:01:00       2019-11-21  13:37:06.597000  -2 days
#
# [8 rows x 21 columns]

# %% [markdown]
# **Se observa que en los casos donde la fecha otorgado es anterior a la fecha del turno el tipo de turno es práctica, el servicio es diagnóstico por imágenes y es sobreturno**

# %%
df_1 = df_1.drop(df_1[df_1.DifDias < x].index)

# %%
df_1.loc[(df_1.DifDias < x)]
# Out:
# Empty DataFrame
# Columns: [CentroDeAtencion, Prestador, Recurso, Servicio, FechaDelTurno, EstadoDelTurno, Sexo, Edad, HC, TipoDeTurno, Prestacion, FechaOtorgado, Localidad, Provincia, Canal, EsSobreTurno, FechaDiaDelTurno, HoraTurno, FechaDiaOtorgado, HoraOtorgado, DifDias]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Creacion de campos nuevos

# %% [markdown]
# #### Agregamos al data frame el día de la semana de la fecha del turno

# %%
df_1['DiaTurno'] = df_1['FechaDelTurno'].apply(lambda time: time.dayofweek)
df_1['MesTurno'] = df_1['FechaDelTurno'].apply(lambda time: time.month)
df_1['DiaTurnoNombre'] = df_1['DiaTurno'].apply(lambda x: 'Lunes' if x == 0 else 'Martes' if x == 1
                                 else 'Miercoles' if x == 2 else 'Jueves' if x == 3
                                 else 'Viernes' if x== 4 else 'Sabado' if x == 5
                                 else 'Domingo' )

# %%
df_1.dtypes
# Out:
# CentroDeAtencion              int64
# Prestador                    object
# Recurso                       int64
# Servicio                     object
# FechaDelTurno        datetime64[ns]
# EstadoDelTurno               object
# Sexo                         object
# Edad                          int64
# HC                            int32
# TipoDeTurno                  object
# Prestacion                   object
# FechaOtorgado        datetime64[ns]
# Localidad                    object
# Provincia                    object
# Canal                        object
# EsSobreTurno                 object
# FechaDiaDelTurno             object
# HoraTurno                    object
# FechaDiaOtorgado             object
# HoraOtorgado                 object
# DifDias             timedelta64[ns]
# DiaTurno                      int64
# MesTurno                      int64
# DiaTurnoNombre               object
# dtype: object

# %%
df_1
# Out:
#          CentroDeAtencion Prestador  Recurso              Servicio  \
# 0                       1      OTRO      253  GUARDIA DE PEDIATRIA
# 1                       1      OTRO      253  GUARDIA DE PEDIATRIA
# 2                       1      OTRO      253  GUARDIA DE PEDIATRIA
# 3                       1      OTRO      253  GUARDIA DE PEDIATRIA
# 4                       1      OTRO      253  GUARDIA DE PEDIATRIA
# ...                   ...       ...      ...                   ...
# 1311778                 1      OTRO      180              UROLOGÍA
# 1311779                 2      OTRO      168             ECOGRAFIA
# 1311780                 3      OTRO      367           CARDIOLOGÍA
# 1311781                 1      OTRO      174             ECOGRAFIA
# 1311782                 1      OTRO      454           RADIOGRAFIA
#
#               FechaDelTurno EstadoDelTurno Sexo  Edad      HC  \
# 0       2018-01-01 11:57:00       Atendido    F     4       0
# 1       2018-01-01 12:20:00       Atendido    M     3       1
# 2       2018-01-01 12:23:00       Atendido    M     3       2
# 3       2018-01-01 12:27:00       Atendido    M     3       3
# 4       2018-01-01 12:38:00       Atendido    F     3       4
# ...                     ...            ...  ...   ...     ...
# 1311778 2019-12-30 19:45:00       Atendido    M    18  169488
# 1311779 2019-12-30 19:45:00       Atendido    M     9  154994
# 1311780 2019-12-30 19:45:00       Atendido    F    41    7332
# 1311781 2019-12-31 11:29:00       Atendido    F    28   48486
# 1311782 2019-12-31 14:23:00       Atendido    M     2    5877
#
#                 TipoDeTurno  ...     Canal EsSobreTurno FechaDiaDelTurno  \
# 0        Ulterior / Control  ...       NaN           SI       2018-01-01
# 1        Ulterior / Control  ...       NaN           SI       2018-01-01
# 2        Ulterior / Control  ...       NaN           SI       2018-01-01
# 3        Ulterior / Control  ...       NaN           SI       2018-01-01
# 4        Ulterior / Control  ...       NaN           SI       2018-01-01
# ...                     ...  ...       ...          ...              ...
# 1311778         Primera Vez  ...  Telefono           NO       2019-12-30
# 1311779            Práctica  ...  Telefono           NO       2019-12-30
# 1311780         Primera Vez  ...  Telefono           NO       2019-12-30
# 1311781            Práctica  ...       NaN           SI       2019-12-31
# 1311782            Práctica  ...       NaN           SI       2019-12-31
#
#         HoraTurno FechaDiaOtorgado     HoraOtorgado DifDias DiaTurno MesTurno  \
# 0        11:57:00       2018-01-01  11:58:10.047000  0 days        0        1
# 1        12:20:00       2018-01-01  12:20:46.097000  0 days        0        1
# 2        12:23:00       2018-01-01  12:25:39.333000  0 days        0        1
# 3        12:27:00       2018-01-01  12:27:55.193000  0 days        0        1
# 4        12:38:00       2018-01-01  12:39:04.563000  0 days        0        1
# ...           ...              ...              ...     ...      ...      ...
# 1311778  19:45:00       2019-12-30  19:26:27.157000  0 days        0       12
# 1311779  19:45:00       2019-12-16  18:10:37.720000 14 days        0       12
# 1311780  19:45:00       2019-12-30  14:50:02.807000  0 days        0       12
# 1311781  11:29:00       2019-12-31  11:29:53.007000  0 days        1       12
# 1311782  14:23:00       2019-12-31  14:23:49.333000  0 days        1       12
#
#         DiaTurnoNombre
# 0                Lunes
# 1                Lunes
# 2                Lunes
# 3                Lunes
# 4                Lunes
# ...                ...
# 1311778          Lunes
# 1311779          Lunes
# 1311780          Lunes
# 1311781         Martes
# 1311782         Martes
#
# [1310004 rows x 24 columns]

# %%
df_1.Prestacion.value_counts()
# Out:
# CONSULTA MEDICA                                        780894
# Prestaciones multiples                                  94027
# MODULO KINESIO-FISIO + MAGNETO Y/O LASER                90177
# TERAPIA OCUPACIONAL                                     40688
# CONSULTA OFTALMOLOGICA VESTIDA                          25895
#                                                         ...
# CONSULTA DIFERENCIADA MEDICINA REPRODUCTIVA                 1
# RADIOGRAFIA CLAVICULA IZQUIERDA FRENTE 30º CEFALICO         1
# RADIOGRAFIA DE MANO IZQUIERDA OBLICUA                       1
# RADIOGRAFIA DE MUÑECA DERECHA PERFIL ESTRICTO               1
# ANGIORESONANCIA CEREBRAL VENOSA                             1
# Name: Prestacion, Length: 756, dtype: int64

# %%
df_1.loc[(df_1.Prestacion != 'CONSULTA MEDICA'), 'Prestacion'] = 'OTRA'

# %%
df_1.Prestacion.value_counts()
# Out:
# CONSULTA MEDICA    780894
# OTRA               529110
# Name: Prestacion, dtype: int64

# %% [markdown]
# ### Chequeo puntual del Servicio

# %% [markdown]
# #### Descartamos los registros de Servicio = demanda chequeo o guardia

# %%
df_1.Servicio.unique()
# Out:
# array(['GUARDIA DE PEDIATRIA', 'CARDIOLOGÍA', 'KINESIOL Y FISIOTERAPIA',
#        'GINECO Y OBSTETRICIA', 'DEMANDA DE PEDIATRÍA', 'HEMOSTASIA',
#        'ANESTESIA', 'HEMATOLOGIA PRACTICAS', 'ENDOCRINOLOGÍA',
#        'ORTOPEDIA Y TRAUMATO', 'REUMATOLOGÍA', 'DERMATOLOGÍA',
#        'NUTRICIÓN', 'UROLOGÍA', 'PEDIATRÍA', 'AUDIOLOGÍA',
#        'GUARDIA DE TRAUMATO DIA', 'NEUROCIRUGÍA', 'GASTROENTEROLOGÍA',
#        'OTORRINOLARINGOLOGÍA', 'NEUROLOGÍA', 'HEMATOLOGÍA',
#        'ANATOMÍA PATOLÓGICA B', 'ONCOLOGÍA', 'OTORRINOLARINGOLOGIA INF',
#        'INFECTOLOGÍA', 'CLÍNICA MÉDICA', 'DEMANDA DE ORL INF',
#        'GASTROENTEROLOGÍA INF', 'DEMANDA DE ORL', 'NEONATOLOGÍA',
#        'GOTEO DE HIERRO', 'DIABETOLOGIA Y NUTRIC', 'CIRUGÍA DE TÓRAX',
#        'NUTRICIÓN INFANTIL', 'DERMATOLOGÍA INF',
#        'GINECOLOGIA PRACTICAS CP', 'GINECOLOGÍA', 'NEUMONOLOGÍA INF',
#        'CIRUGÍA GENERAL', 'CARDIOLOGÍA INF', 'ALERGIA E INMUNOLOGÍA INF',
#        'ALERGIA E INMUNOLOGÍA ', 'HEMATOLOGÍA INF', 'CIRUGÍA PLÁSTICA',
#        'UROLOGÍA INF', 'HOSPITAL DE DÍA', 'UNIDAD DEL DOLOR',
#        'CIRUGÍA VASCULAR PERIF', 'ORTOPEDIA Y TRAUMATO INF',
#        'REUMATOLOGÍA INF', 'CIRUGÍA GENERAL INF',
#        'DEMANDA DE DERMATOLOGIA', 'NEFROLOGÍA INF', 'ENDOCRINOLOGÍA INF',
#        'HIPERTENSIÓN ARTERIAL', 'PSICOMOTRICIDAD', 'PSICOLOGÍA INF',
#        'DEMANDA DE GASTROENT', 'DEMANDA DE NEUROLOGÍA', 'NEUROLOGÍA INF',
#        'CABEZA Y CUELLO', 'PSICOLOGÍA', 'NEFROLOGÍA', 'NEUMONOLOGÍA',
#        'DIABETOLOGIA Y NUTRIC INF', 'FERTILIDAD', 'GENETICA',
#        'DEMANDA DE ENDOCRINOLOGIA', 'CHEQUEO PEDIATRICO',
#        'NEUROCIRUGÍA INF', 'ARRITMOLOGÍA', 'CIRUGÍA CARDIOVASCULAR',
#        'PSIQUIATRÍA', 'ANDROLOGÍA', 'ADOLESCENCIA',
#        'CUENTAS PROPIAS ALERGIA E INMUNOLOGIA', 'CIRUGÍA PLÁSTICA INF',
#        'HEMOSTASIA PRACTICAS',
#        'CUENTAS PROPIAS ALERGIA E INMUNOLOGIA INF', 'CHEQUEO UCC',
#        'HEMODINAMIA', 'DEMANDA DE GASTRO INF',
#        'DEMANDA DE NEUROLOGIA INF', 'DERMOCOSMETICA', 'MICOLOGIA',
#        'MEDICINA FETAL', 'OFTALMOLOGÍA', 'DEMANDA DE OFTALMOLOGIA',
#        'DEPORTOLOGÍA', 'FONOAUDIOLOGIA INF', 'ANATOMIA PATOLOGICA A',
#        'FONOAUDIOLOGIA', 'HEMOTERAPIA', 'RADIOGRAFIA', 'ECOGRAFIA',
#        'DEMANDA DE ONCOLOGIA', 'CUIDADOS PALIATIVOS INF',
#        'INFECTOLOGÍA INF', 'MAMOGRAFIA', 'RESONANCIA', 'TOMOGRAFIA',
#        'ENFERMEDADES METABOLICAS', 'TERAPIA OCUPACIONAL', 'VIROLOGIA',
#        'DEMANDA DE HEMATOLOGIA', 'TERAPIA OCUPACIONAL INF'], dtype=object)

# %%
for i in ['REUMATOLOGÍA INF','ENDOCRINOLOGÍA INF',
          'DERMATOLOGÍA INF', 'DIABETOLOGIA Y NUTRIC INF',
          'NEUMONOLOGÍA INF', 'NEFROLOGÍA INF', 'ALERGIA E INMUNOLOGÍA INF',
          'ORTOPEDIA Y TRAUMATO INF','DIABETOLOGIA Y NUTRIC INF',
          'OTORRINOLARINGOLOGIA INF','NEUROLOGÍA INF', 
          'HEMATOLOGÍA INF', 'NUTRICIÓN INFANTIL',
          'CARDIOLOGÍA INF', 'GASTROENTEROLOGÍA INF'
          'DEMANDA DE GASTRO INF', 'INFECTOLOGÍA INF'
          'PSICOLOGÍA INF', 'CIRUGÍA PLÁSTICA INF',
          'CIRUGÍA GENERAL INF', 'UROLOGÍA INF',
          'FONOAUDIOLOGIA INF', 'NEUROCIRUGÍA INF',
          'GUARDIA DE TRAUMATO DIA', 
          'OTORRINOLARINGOLOGIA INF', 'DEMANDA DE PEDIATRÍA',
          'PEDIATRÍA', 'DEMANDA DE ORL INF',
          'GUARDIA DE PEDIATRIA', 'CHEQUEO PEDIATRICO']:
    df_1 = df_1.drop(df_1[df_1['Servicio'] == i].index)

# %% [markdown]
# ## Incorporacion de la información climática al data frame

# %% [markdown]
# #### Agregamos la columna de precipitación del data frame clima

# %%
df_clima_r
# Out:
#     FechaDiaDelTurno PrecipMM
# 0         01/01/2018     ----
# 1         02/01/2018      0.0
# 2         03/01/2018      0.0
# 3         04/01/2018      0.0
# 4         05/01/2018      0.0
# ..               ...      ...
# 725       27/12/2019      0.0
# 726       28/12/2019      0.0
# 727       29/12/2019     10.0
# 728       30/12/2019    130.0
# 729       31/12/2019      0.0
#
# [730 rows x 2 columns]

# %%
 df_clima_r['FechaDiaDelTurno'] = pd.to_datetime(df_clima_r.FechaDiaDelTurno)

# %%
df_1['FechaDiaDelTurno'] = pd.to_datetime(df_1.FechaDiaDelTurno)

# %%
df_1_1= df_clima_r.merge(df_1, on=['FechaDiaDelTurno'])
df_1_1.head()
# Out:
#   FechaDiaDelTurno PrecipMM  CentroDeAtencion Prestador  Recurso  \
# 0       2018-02-01      0.0                 4      OTRO      213
# 1       2018-02-01      0.0                 4      OTRO      506
# 2       2018-02-01      0.0                 4      OTRO      213
# 3       2018-02-01      0.0                 4      OTRO      213
# 4       2018-02-01      0.0                 4      OTRO      506
#
#                   Servicio       FechaDelTurno EstadoDelTurno Sexo  Edad  ...  \
# 0  KINESIOL Y FISIOTERAPIA 2018-02-01 07:30:00        Ausente    F    50  ...
# 1  KINESIOL Y FISIOTERAPIA 2018-02-01 07:30:00       Atendido    M    36  ...
# 2  KINESIOL Y FISIOTERAPIA 2018-02-01 07:30:00       Atendido    F    69  ...
# 3  KINESIOL Y FISIOTERAPIA 2018-02-01 07:30:00        Ausente    M    35  ...
# 4  KINESIOL Y FISIOTERAPIA 2018-02-01 07:30:00        Ausente    M    45  ...
#
#    Provincia Canal EsSobreTurno HoraTurno FechaDiaOtorgado     HoraOtorgado  \
# 0       otro   NaN           NO  07:30:00       2018-01-12  07:27:28.427000
# 1       otro   NaN           NO  07:30:00       2018-01-16  10:01:43.983000
# 2       otro   NaN           NO  07:30:00       2018-01-24  13:01:56.890000
# 3    cordoba   NaN           NO  07:30:00       2018-01-23  17:23:36.427000
# 4    cordoba   NaN           NO  07:30:00       2018-01-23  09:02:10.713000
#
#   DifDias DiaTurno MesTurno DiaTurnoNombre
# 0 20 days        3        2         Jueves
# 1 16 days        3        2         Jueves
# 2  8 days        3        2         Jueves
# 3  9 days        3        2         Jueves
# 4  9 days        3        2         Jueves
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Opcional

# %% [markdown]
# #### Despersonalizacion HC

# %%
from hashlib import md5

# %%
def hashit(val):
    if isinstance(val, float): 
        return  md5(str(val).encode('utf-8')).hexdigest() 
    elif isinstance(val, int): 
        return  md5(str(val).encode('utf-8')).hexdigest() 
    return md5(val.encode('utf-8')).hexdigest()

# %%
df_1_1['HC_hash']=df_1['HC'].apply(hashit)

# %%
df_1_1.HC_hash.unique()

# %% [markdown]
# #### Despersonalizacion Recurso

# %%
df_1_1['Recurso_hash']=df_1['Recurso'].apply(hashit)

# %%
df_1_1.Recurso_hash.value_counts()

# %%
df_1_1

# %% [markdown]
# # Test de Integridad

# %%
def test1(df_1):
    """
    Devuelve 0 si el test es exitoso, y 1 si el test falla
    """
    data_filter1 = df_1[(df_1.CentroDeAtencion < 0)]
    if len(data_filter1) == 0: 
        return 0 
    else:  return 1

# %%
def test2(df_1):
    """
    Devuelve 0 si el test es exitoso, y 1 si el test falla
    """
    data_filter1 = df_1[(df_1.Recurso < 0)]
    if len(data_filter1) == 0: 
        return 0 
    else:  return 1

# %%
def test3(df_1):
    """
    Devuelve 0 si el test es exitoso, y 1 si el test falla
    """
    data_filter1 = df_1[(df_1.Edad < 0)]
    if len(data_filter1) == 0: 
        return 0 
    else:  return 1

# %%
def test4(df_1):
    """
    Devuelve 0 si el test es exitoso, y 1 si el test falla
    """
    data_filter1 = df_1[(df_1.HC < 0)]
    if len(data_filter1) == 0: 
        return 0 
    else:  return 1

# %%
 def test_integridad(df):
    """
    Ejecuta uno por uno los tests e informa el resultado
    """
    print('Test 1: %s' % ('ERROR' if test1(df) else 'EXITOSO'))
    print('Test 2: %s' % ('ERROR' if test2(df) else 'EXITOSO'))
    print('Test 3: %s' % ('ERROR' if test2(df) else 'EXITOSO'))  
    print('Test 4: %s' % ('ERROR' if test2(df) else 'EXITOSO'))
    return

# %%
test_integridad(df_1)

# %%
df_1_1.EsSobreTurno.unique()
